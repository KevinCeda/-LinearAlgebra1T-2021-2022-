# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinCeda/-LinearAlgebra1T-2021-2022-/blob/main/Assignment10_Ceda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Linear Algebra for ECE
# Now that you have a fundamental knowledge about linear combination, we'll try to visualize it using scientific programming.

# %% [markdown]
# ##Objectives
#
#
# At the end of this activity you will be able to:
#
#     1. Be familiar with representing linear combinations in the 2-dimensional plane.
#     2. Visualize spans using vector fields in Python.
#     3. Perform vector fields operations using scientific programming.

# %% [markdown]
# ##Discussion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##Linear Combination
#
#
# It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components
#
# We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$
#
# In mathematics, a linear combination is an expression created by multiplying each term by a constant and then adding the results. [1]

# %% [markdown]
# ![Screenshot 2021-11-14 at 23-26-27 LinearAlgebra Assignment10_Ligutan ipynb at main · shanedligutan LinearAlgebra .png](data:image/png;base64,...)

# %% [markdown]
# Fig. 2: Linear combination of 2 vectors

# %%
vectX =  np.array([2,5])
vectY =  np.array([7,9])

# %% [markdown]
# Span of single vectors
#
# As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$
#
# What exactly is a span? All linear combinations of these vectors make up the span of a set of vectors. Consider the vectors (0,1) and (1,0); the x-y plane would be spanned by these two vectors. [2]

# %% [markdown]
# ![Screenshot 2021-11-14 at 23-28-34 LinearAlgebra Assignment10_Ligutan ipynb at main · shanedligutan LinearAlgebra .png](data:image/png;base64,...)

# %% [markdown]
# Fig. 3: Vector Coordinates

# %%
c = np.arange(-10,10,0.125)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
c = np.arange(-15,15,0.5)

plt.scatter(c*vectY[0],c*vectY[1])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# Span of a linear combination of vectors
#
# So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below:
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix}, c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %% [markdown]
# ![Screenshot 2021-11-14 at 23-30-41 LinearAlgebra Assignment10_Ligutan ipynb at main · shanedligutan LinearAlgebra .png](data:image/png;base64,...)

# %% [markdown]
#     Fig. 4: Span of vectors
#
# When we conceive of vectors as arrows, a span can be difficult to comprehend. We can, on the other hand, think of them as points. As a result, the span of most pairs of vectors in our span example ends up being the entire infinite two-dimensional plane. When the vectors are all on the same line, their span is also a line. [3]

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectP + vectQ
spanRx = c1*vectP[0] + c2*vectQ[0]
spanRy = c1*vectP[1] + c2*vectQ[1]
##plt.scatter(R*vectA[0],R*vectA[1])
##plt.scatter(R*vectB[0],R*vectB[1])
plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# Take note that if vectors are seen to be as a 2-dimensional span we can say it has a Rank of 2 or $\mathbb{R}^2$. But if the span of the linear combination of vectors are seen to be like a line, they are said to be linearly dependent and they have a rank of 1 or $\mathbb{R}^1$.

# %% [markdown]
# ##Activity
#
#
#
#
# Task 1
#
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.
# $$S = \begin{bmatrix} 7\\8 \\\end{bmatrix} , L = \begin{bmatrix} 9\\5 \\\end{bmatrix} $$
# $$ 3x+2y-37z= 0$$

# %%
vectS = np.array([7, 8])
vectL = np.array([9,5])

P = np.arange(-10,10,1)

V1, V2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = V1*vectA[0] + V2*vectB[0]
spanRy = V1*vectA[1] + V2*vectB[1]

plt.scatter(spanRx,spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# *Conclusion guide*
#
# For your conclusion synthesize the concept and application of the laboratory. Briefly discuss what you have learn and achieved in this activity. At the end of your conclusion try to answer the question : "How can you apply the concept of linear combination in engineering or real-life situations?".

# %% [markdown]
# In this laboratory experiment, plotting is a data science approach of making a graph that involves presenting many points or variables on an x-y axis to highlight the relationship between the data points. The Plot function is necessary to create the numerous types of graphs and visualizations that are mentioned in Matplotlib. Because Matplotlib is recognized for plotting and charting graphs, many of the data science functions in the library are connected to the process of data visualization or modeling. Matrix algebra is well supported by libraries like NumPy and matplotlib. In the scientific literature, there are several linear operators that are useful. We used Numpy and matplotlib python methods to build linear combinations and vector spaces. In statistics, linear models are used to describe observations or target variables as linear combinations of features. A mapping from model space to data space may be conceived of as a linear operator. Every linear operator has a matrix representation. Using Python tools that allow us to plot vector fields, we may visualize the span of vectors. We were able to display linear combinations in the 2-d plane by utilizing Python programming to perform vector fields operations.
